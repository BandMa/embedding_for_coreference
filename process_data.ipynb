# %%
slot_des = {
    "hotel-pricerange":["price budget of the hotel", "preferred cost of the hotel"],
    "hotel-type": ["what is the type of the hotel", "type of hotel building"],
    "hotel-parking":["parking facility at the hotel", "whether the hotel has parking", "does the hotel have parking"],
    "hotel-bookstay":["length of stay at the hotel", "how many days you want to stay at the hotel for"],
    "hotel-bookday":["day of the hotel booking", "what day of the week you want to start staying at the hotel"],
    "hotel-bookpeople":["number of people for the hotel booking", "how many people are staying at the hotel"],
    "hotel-area":["area or place of the hotel", "rough location of the hotel", "preferred location of the hotel"],
    "hotel-stars":["star rating of the hotel", "rating of the hotel out of five stars"],
    "hotel-internet":["internet option at the hotel", "whether the hotel has internet"],
    "hotel-name":["name of the hotel", "which hotel are you looking for"],
    "train-destination":["destination of the train", "what train station you want to travel to", "destination or drop-off location of the train"],
    "train-day":["day of the train", "what day you want to take the train"],
    "train-departure":["departure location of the train", "what train station you want to leave from"],
    "train-arriveby":["arrival time of the train", "what time you want the train to arrive at your destination station by", "when you want to arrive at your destination by train"],
    "train-bookpeople":["number of people booking for train", "how many people you need train booking for", "how many train tickets you need"],
    "train-leaveat":["leaving time for the train", "what time you want the train to leave your departure station by", "when you want to arrive at your destination by train"],
    "attraction-type":["type of the attraction", "type of attraction or point of interest"],
    "attraction-area":["area or place of the attraction", "area to search for attractions", "preferred location for attraction"],
    "attraction-name":["name of the attraction", "which attraction are you looking for"],
    "restaurant-bookpeople":["number of people booking the restaurant", "how many people for the restaurant reservation"],
    "restaurant-bookday":["day of the restaurant booking", "what day of the week to book the table at the restaurant"],
    "restaurant-booktime":["time of the restaurant booking", "what time to book the table at the restaurant" ],
    "restaurant-food":["food type for the restaurant", "the cuisine of the restaurant you are looking for"],
    "restaurant-pricerange":["price budget for the restaurant", "preferred cost of the restaurant"],
    "restaurant-name":["name of the restaurant", "which restaurant are you looking for"],
    "restaurant-area":["area or place of the restaurant", "preferred location of restaurant"],
    "taxi-leaveat":["leaving time of taxi", "when you want the taxi to pick you up", "what time you want the taxi to leave your departure location by"],
    "taxi-destination":["destination of taxi", "where you want the taxi to drop you off", "what place do you want the taxi to take you to"],
    "taxi-departure":["departure location of taxi", "where you want the taxi to pick you up", "what place do you want to meet the taxi"],
    "taxi-arriveby":["arrival time of taxi", "when you want the taxi to drop you off at your destination", "what time you to arrive at your destination by taxi"],
    "bus-people":["number of people booking bus tickets", "how many people are riding the bus"],
    "bus-leaveAt":["leaving time of bus", "when you want the bus to pick you up", "what time you want the bus to leave your departure location by"],
    "bus-destination":["destination of taxi", "where you want the bus to drop you off", "what place do you want the bus to take you to"],
    "bus-day":["day to use the bus tickets", "what day of the week you want to ride the bus"],
    "bus-arriveBy":["arrival time of bus", "when you want the bus to drop you off at your destination", "what time you to arrive at your destination by bus"],
    "bus-departure":["departure location of bus", "where you want the bus to pick you up", "what place do you want to meet the bus"],
    "hospital-department":["name of hospital department", "type of medical care", "what department of the hospital are you looking for"]
}

slot_des = {k:v[0] for k,v in slot_des.items()}
slot_des
# Out:
# {'hotel-pricerange': 'price budget of the hotel',
#  'hotel-type': 'what is the type of the hotel',
#  'hotel-parking': 'parking facility at the hotel',
#  'hotel-bookstay': 'length of stay at the hotel',
#  'hotel-bookday': 'day of the hotel booking',
#  'hotel-bookpeople': 'number of people for the hotel booking',
#  'hotel-area': 'area or place of the hotel',
#  'hotel-stars': 'star rating of the hotel',
#  'hotel-internet': 'internet option at the hotel',
#  'hotel-name': 'name of the hotel',
#  'train-destination': 'destination of the train',
#  'train-day': 'day of the train',
#  'train-departure': 'departure location of the train',
#  'train-arriveby': 'arrival time of the train',
#  'train-bookpeople': 'number of people booking for train',
#  'train-leaveat': 'leaving time for the train',
#  'attraction-type': 'type of the attraction',
#  'attraction-area': 'area or place of the attraction',
#  'attraction-name': 'name of the attraction',
#  'restaurant-bookpeople': 'number of people booking the restaurant',
#  'restaurant-bookday': 'day of the restaurant booking',
#  'restaurant-booktime': 'time of the restaurant booking',
#  'restaurant-food': 'food type for the restaurant',
#  'restaurant-pricerange': 'price budget for the restaurant',
#  'restaurant-name': 'name of the restaurant',
#  'restaurant-area': 'area or place of the restaurant',
#  'taxi-leaveat': 'leaving time of taxi',
#  'taxi-destination': 'destination of taxi',
#  'taxi-departure': 'departure location of taxi',
#  'taxi-arriveby': 'arrival time of taxi',
#  'bus-people': 'number of people booking bus tickets',
#  'bus-leaveAt': 'leaving time of bus',
#  'bus-destination': 'destination of taxi',
#  'bus-day': 'day to use the bus tickets',
#  'bus-arriveBy': 'arrival time of bus',
#  'bus-departure': 'departure location of bus',
#  'hospital-department': 'name of hospital department'}

# %%
import jsonlines

data_list = []
data_path = 'D:\Python4work\paper_modified_test\gte_ft_data.jsonl'
with open(data_path, 'r') as file_obj:
    for line in jsonlines.Reader(file_obj):
        data_list.append(line)

# %%
data_list[0]['diag_seen_slots']
# Out:
# {'hotel-name': 'alyesbray lodge guest house',
#  'hotel-bookday': 'sunday',
#  'hotel-bookstay': '5',
#  'hotel-bookpeople': '8',
#  'restaurant-name': 'don pasquale pizzeria'}

# %%
refer_dict = {}
for k,v in data_list[0]['class_type'].items():
    if v == 'refer':
        refer_dict[k] = v

refer_dict
# Out:
# {'restaurant-bookday': 'refer', 'restaurant-bookpeople': 'refer'}

# %%
refer_dict = {}
for k,v in data_list[0]['referred'].items():
    if v != 'none':
        refer_dict[k] = v

refer_dict
# Out:
# {'restaurant-bookday': 'hotel-bookday',
#  'restaurant-bookpeople': 'hotel-bookpeople'}

# %%
processed_data = []
for i in range(len(data_list)):
    query = [' '.join(data_list[i]['user_utt']), ' '.join(data_list[i]['system_utt'])][::-1]
    refer = {}
    for k,v in data_list[i]['referred'].items():
        if v != 'none':
            refer[k] = v
    processed_data.append({'query': query, 'corpus': refer.copy(), 'dialog_seen': data_list[i]['diag_seen_slots']})

# %%
processed_data
# Out:
# [{'query': ['a very nice place in the centre . need a reservation ?',
#    "yes , i do . i ' ll need it booked for the same day , same people , and we ' d like to eat at 19 : 00 ."],
#   'corpus': {'restaurant-bookday': 'hotel-bookday',
#    'restaurant-bookpeople': 'hotel-bookpeople'},
#   'dialog_seen': {'hotel-name': 'alyesbray lodge guest house',
#    'hotel-bookday': 'sunday',
#    'hotel-bookstay': '5',
#    'hotel-bookpeople': '8',
#    'restaurant-name': 'don pasquale pizzeria'}},
#  {'query': ['booking was successful . the table will be reserved for 15 minutes . reference number is : gvm0pam2 .',
#    "great . one more thing . can you book a taxi between the two places ? i ' d like to arrive at the restaurant in time for my reservation ."],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'hotel-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'hotel-name': 'alyesbray lodge guest house',
#    'hotel-bookday': 'sunday',
#    'hotel-bookstay': '5',
#    'hotel-bookpeople': '8',
#    'restaurant-name': 'don pasquale pizzeria',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '19:00'}},
#  {'query': ['i have made your booking here is the information : booking was successful . the table will be reserved for 15 minutes . reference number is : vvsoh0tq .',
#    "what ' s a good college to visit near the restaurant ?"],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'british',
#    'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'cotto',
#    'restaurant-bookday': 'friday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '12:30'}},
#  {'query': ['great news ! i was able to reserve your table for 2 at the 11 : 45 time . they will hold the table for 15 minutes . reference number is : gfil3ug5 .',
#    'thank you . i am also looking for places to go in the same area as the restaurant .'],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-name': 'charlie chan',
#    'restaurant-bookday': 'tuesday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '11:45'}},
#  {'query': ['the booking went through , your table is reserved for 15 minutes starting at 16 : 15 . reference number is bt75stqi .',
#    "thanks ! i ' m also looking for a hotel near that restaurant ."],
#   'corpus': {'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'east',
#    'restaurant-name': 'yu garden',
#    'restaurant-bookday': 'monday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '16:15'}},
#  {'query': ['booking was successful . reference number is : 36n9vcad . is there anything else i can help with ?',
#    'what is the train schedule from birmingham new street like ? i need to arrive at 13 : 45 .'],
#   'corpus': {'train-day': 'hotel-bookday'},
#   'dialog_seen': {'hotel-area': 'dontcare',
#    'hotel-type': 'hotel',
#    'hotel-name': 'huntingdon marriott hotel',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '2',
#    'hotel-bookstay': '5'}},
#  {'query': ['yes there are 15 restaurants that are a similar price range . did you still want italian ?',
#    "type of food doesn ' t matter . which is the best one ? i ' ll book that ."],
#   'corpus': {'restaurant-food': 'restaurant-name'},
#   'dialog_seen': {'restaurant-name': 'dontcare',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '14:15',
#    'restaurant-area': 'centre'}},
#  {'query': ['sorry , the arrival time is actually 16 : 58 . how many tickets would you like ?',
#    'i need tickets for the same group of people going to the restaurant with me .'],
#   'corpus': {'train-bookpeople': 'restaurant-bookpeople'},
#   'dialog_seen': {'restaurant-name': 'bangkok city',
#    'restaurant-food': 'thai',
#    'restaurant-area': 'centre',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '19:30',
#    'train-arriveby': '17.58',
#    'train-day': 'monday',
#    'train-destination': 'kings lynn',
#    'train-departure': 'cambridge'}},
#  {'query': ['your booking was successful and the reference number is elypaxqz .',
#    "thank you . i ' m also looking for a museum to go to in the same area ."],
#   'corpus': {'attraction-area': 'hotel-area'},
#   'dialog_seen': {'hotel-type': 'hotel',
#    'hotel-area': 'centre',
#    'hotel-pricerange': 'expensive',
#    'hotel-name': 'gonville hotel',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '1',
#    'hotel-bookstay': '1'}},
#  {'query': ['alright , i have your restaurant booking . your reference number is : dhdb0h4v . what are you looking for in a hotel , so i can narrow down the choices ?',
#    'something in the same area as the restaurant . it should also be in that same price range .'],
#   'corpus': {'hotel-pricerange': 'restaurant-pricerange',
#    'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'british',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'centre',
#    'restaurant-name': 'midsummer house restaurant',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '16:30'}},
#  {'query': ['i will look a taxi up for you .',
#    'thank you very much ! can you please make sure that it arrives at the restaurant by the time of my reservation ?'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'hotel-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-food': 'british',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'centre',
#    'restaurant-name': 'midsummer house restaurant',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '16:30',
#    'hotel-area': 'centre',
#    'hotel-pricerange': 'expensive',
#    'hotel-type': 'hotel',
#    'hotel-name': 'university arms hotel'}},
#  {'query': ['is there anything further that i can assist you with today ?',
#    "yes , i ' ll need a taxi from the restaurant to the hotel . i want to leave the restaurant by 18 : 30 ."],
#   'corpus': {'taxi-destination': 'hotel-name'},
#   'dialog_seen': {'restaurant-food': 'gastropub',
#    'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'taxi-departure': 'cow pizza kitchen and bar',
#    'hotel-stars': '4',
#    'hotel-parking': 'yes',
#    'hotel-name': 'allenbell'}},
#  {'query': ['pizza express fen ditton is located at jesus lane fen ditton . is there anything else i can help you with ?',
#    'yes . i would like to leave the restaurant by 11 : 15 and i would like to book a taxi to commute between the hotel and the restaurant .'],
#   'corpus': {'taxi-destination': 'hotel-name'},
#   'dialog_seen': {'hotel-internet': 'yes',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'moderate',
#    'hotel-name': 'archway house',
#    'hotel-bookday': 'tuesday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '4',
#    'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-food': 'italian'}},
#  {'query': ["alright , you ' re all booked ! your reference number is ywekso7h . is there anything else i can help you with ?",
#    "i ' m also looking for a place to visit within the same area as the restaurant . do you have any recommendations ?"],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'the oak bistro',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '16:00'}},
#  {'query': ["the cambridge contemporary art museum is fantastic , and it ' s free . would you like more information ?",
#    'i will need a taxi to take me from the museum to the restaurant . obviously it needs to get me there before my reservation .'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'the oak bistro',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '16:00',
#    'attraction-area': 'centre',
#    'attraction-type': 'museum'}},
#  {'query': ['your booking was successful with a reference number of s1htvv32 . is there anything else i can do for you today ?',
#    'i need a taxi please between the 2 places . i want to leave the attraction by 2 : 30 .'],
#   'corpus': {'taxi-destination': 'hotel-name'},
#   'dialog_seen': {'attraction-type': 'college',
#    'taxi-departure': 'corpus christi',
#    'hotel-area': 'centre',
#    'hotel-type': 'hotel',
#    'hotel-name': 'university arms hotel',
#    'hotel-bookday': 'tuesday',
#    'hotel-bookpeople': '1',
#    'hotel-bookstay': '1'}},
#  {'query': ['tr5484 leaves at 13 : 50 and costs 4 . 40 pounds . is that fine with you ?',
#    'yes , but i need to book four more people as well .'],
#   'corpus': {'train-bookpeople': 'restaurant-bookpeople'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '11:45',
#    'restaurant-name': 'fitzbillies',
#    'train-arriveby': '21:30',
#    'train-departure': 'cambridge',
#    'train-destination': 'ely',
#    'train-day': 'monday'}},
#  {'query': ['where will you be departing from ?',
#    'i will be traveling between the hotel and restaurant .'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-name': 'alexander bed and breakfast',
#    'hotel-bookday': 'friday',
#    'hotel-bookpeople': '4',
#    'hotel-bookstay': '3',
#    'restaurant-area': 'east',
#    'restaurant-food': 'indian',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'rajmahal',
#    'restaurant-bookday': 'friday',
#    'restaurant-bookpeople': '4',
#    'restaurant-booktime': '14:45'}},
#  {'query': ['your restaurant booking was successful . this is the reference number pqa4wknf . it is for saturday at 15 : 30 for 8 people .',
#    'can you book me two taxi cabs that offer groupon discounts to take us to the restaurant ?'],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'dontcare',
#    'restaurant-name': 'kymmoy',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '15:30'}},
#  {'query': ["i don ' t think we have any affiliations with groupon . is there anything else i can help you with today ?",
#    "i ' m looking for a place to stay . the hotel should be in the same price range as the restaurant and should be in the type of guesthouse ."],
#   'corpus': {'hotel-pricerange': 'restaurant-pricerange',
#    'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'dontcare',
#    'restaurant-name': 'kymmoy',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '15:30',
#    'taxi-destination': 'kymmoy'}},
#  {'query': ['i made a reservation for you at saigon city for a party of 7 on tuesday at 12 : 30 . your reference is n2fhz30y . is there anything else i can help you with ?',
#    "wonderful . i ' m also looking for a cool place to check out in the same area ."],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'north',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-food': 'asian oriental',
#    'restaurant-name': 'saigon city',
#    'restaurant-bookday': 'tuesday',
#    'restaurant-bookpeople': '7',
#    'restaurant-booktime': '12:30'}},
#  {'query': ['the address listed for old schools is simply trinity lane . and their postcode is cb21tt . is there anything more i can do for you today ?',
#    'yes , i would also like to find an expensive restaurant in the same area .'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-name': 'old schools'}},
#  {'query': ['is there a price range you would prefer to stay within ?',
#    'no i do not need to stay within a price .'],
#   'corpus': {'restaurant-pricerange': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'british',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'dontcare',
#    'restaurant-bookday': 'tuesday',
#    'restaurant-bookpeople': '6',
#    'restaurant-booktime': '12:30'}},
#  {'query': ['the postcode is cb11ln and address is 98 king street . the phone number there is 01223314960 . anything else ?',
#    "yes , i ' d like to get a taxi from the hotel to the museum please ."],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-pricerange': 'moderate',
#    'hotel-type': 'guesthouse',
#    'hotel-parking': 'yes',
#    'hotel-bookday': 'saturday',
#    'hotel-bookpeople': '1',
#    'hotel-bookstay': '2',
#    'hotel-name': 'acorn guest house',
#    'attraction-type': 'museum',
#    'attraction-name': 'broughton house gallery'}},
#  {'query': ["i ' m sorry , i cannot look up the entry fee to christ ' s college . is there anything else i can do for you today ?",
#    'i also need a restaurant in the same area .'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'college',
#    'attraction-name': "christ's college"}},
#  {'query': ['sure i can help with that . there are no trains going to the town centre . do you have another destination in mind ?',
#    'could you check for a bus ?'],
#   'corpus': {'bus-departure': 'train-departure'},
#   'dialog_seen': {'train-bookpeople': '7',
#    'train-day': 'thursday',
#    'train-departure': 'cambridge',
#    'train-leaveat': '07:15'}},
#  {'query': ['i have booked finches bed & breakfast for you starting sunday for 4 nights for 8 people . your reference number is h7whfpqt . is there anything i may assist with ?',
#    "thank you , yes , i ' d like to also find a nice park to visit while i ' m in town . can you see if there is one near my hotel ?"],
#   'corpus': {'attraction-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'west',
#    'hotel-internet': 'yes',
#    'hotel-parking': 'yes',
#    'hotel-stars': '4',
#    'hotel-name': 'finches bed and breakfast',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '8',
#    'hotel-bookstay': '4'}},
#  {'query': ['there are a few places , mainly churches , that have great architecture . do you want information on any of those ?',
#    'no thank you though . i would like information on greek restaurants that would be in the same area as the churches you suggested , please ?'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'architecture'}},
#  {'query': ['booking was successful . reference number is : ia596hsh . is there anything else i can do for you ?',
#    "yes , i ' ll also need a taxi to commute between the two places . i ' ll need to be at the restaurant by 13 : 30 , of course ."],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'architecture',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'african',
#    'restaurant-name': 'bedouin',
#    'restaurant-bookday': 'thursday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '13:30'}},
#  {'query': ['ok , would you prefer a guesthouse or a hotel ?',
#    'any so long as it is a 2star and has wifi'],
#   'corpus': {'hotel-type': 'hotel-area'},
#   'dialog_seen': {'hotel-pricerange': 'cheap', 'hotel-area': 'dontcare'}},
#  {'query': ['there are 5 expensive italian restaurants around town is there an area you prefer ?',
#    'no any area will work . whatever you recommend . i need a reservation for friday , 3 people at 13 : 45 . please include the reference number .'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-pricerange': 'expensive',
#    'hotel-area': 'dontcare',
#    'hotel-internet': 'yes',
#    'hotel-stars': '2',
#    'hotel-type': 'dontcare',
#    'hotel-name': 'express by holiday inn cambridge',
#    'hotel-bookday': 'friday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '3',
#    'restaurant-food': 'italian',
#    'restaurant-pricerange': 'expensive'}},
#  {'query': ["ok . i ' ve booked a room with a queen sized bed for 3 nights starting monday at the holiday inn cambridge . is there anything else i can help you with ?",
#    'can i get a taxi that will take me to the hotel from the restaurant ?'],
#   'corpus': {'taxi-departure': 'restaurant-name'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-food': 'french',
#    'restaurant-name': 'cote',
#    'hotel-name': 'express by holiday inn cambridge',
#    'hotel-bookday': 'monday',
#    'hotel-bookpeople': '1',
#    'hotel-bookstay': '3'}},
#  {'query': ['sure , what time should i set it up for the taxi to pick you up ?',
#    'well , i need the taxi to pick me up at the restaurant by 09 : 15 . i need the contact number and car type please .'],
#   'corpus': {'taxi-destination': 'hotel-name'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-food': 'french',
#    'restaurant-name': 'cote',
#    'hotel-name': 'express by holiday inn cambridge',
#    'hotel-bookday': 'monday',
#    'hotel-bookpeople': '1',
#    'hotel-bookstay': '3',
#    'taxi-destination': 'holiday inn cambridge',
#    'taxi-departure': 'cote'}},
#  {'query': ['okay . your booking was successful . the reference number is uoe033dz . can i help with anything else today ?',
#    'can you book me a taxi to get me from the cinema to the hotel ?'],
#   'corpus': {'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'cinema',
#    'attraction-name': 'vue',
#    'hotel-area': 'west',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'guesthouse',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '2',
#    'hotel-bookstay': '3'}},
#  {'query': ['where would you like to be picked up ?',
#    'pick me up from the hotel .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'attraction-type': 'architecture',
#    'attraction-name': 'old schools',
#    'hotel-area': 'north',
#    'hotel-pricerange': 'moderate',
#    'hotel-stars': '2',
#    'hotel-bookday': 'saturday',
#    'hotel-bookpeople': '8',
#    'hotel-bookstay': '2',
#    'hotel-name': 'ashley hotel',
#    'taxi-departure': 'old schools',
#    'taxi-leaveat': '21:30'}},
#  {'query': ['there are 21 4 star options . do you need internet or parking ?',
#    "parking doesn ' t matter , but i want it to be in the same area as the restaurant ."],
#   'corpus': {'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-food': 'indian',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'curry garden',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '18:15',
#    'hotel-stars': '4'}},
#  {'query': ['i have two results for you . do you prefer a guesthouse or a hotel',
#    'either will do - which place do you think is better ?'],
#   'corpus': {'hotel-type': 'hotel-parking'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-food': 'indian',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'curry garden',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '18:15',
#    'hotel-stars': '4',
#    'hotel-area': 'centre',
#    'hotel-parking': 'dontcare',
#    'hotel-internet': 'yes'}},
#  {'query': ['the postcode is cb238el , address is unit 8 , viking way , bar hill and there is not an entrance fee listed . can i help you with anything else ?',
#    "yes , can you book me a taxi between those two ? i ' d like to arrive at the restaurant in time for my reservation please ."],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'attraction-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-bookday': 'tuesday',
#    'restaurant-bookpeople': '7',
#    'restaurant-booktime': '12:15',
#    'restaurant-food': 'dontcare',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'bedouin',
#    'attraction-name': 'whale of a time'}},
#  {'query': ['i would be happy to do get a taxi for you . i need the departure location , destination location and the time of travel .',
#    'i would like to leave the restaurant by 8 : 30 .'],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'restaurant-name'},
#   'dialog_seen': {'attraction-name': 'trinity college',
#    'attraction-type': 'college',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'jinling noodle bar',
#    'taxi-leaveat': '08:30'}},
#  {'query': ['sure thing , what time would you like to arrive at your destination ?',
#    'i need to arrive in time for my reservation .'],
#   'corpus': {'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'hotel-area': 'west',
#    'hotel-type': 'hotel',
#    'hotel-internet': 'yes',
#    'hotel-stars': '4',
#    'hotel-name': 'cambridge belfry',
#    'restaurant-name': 'maharajah tandoor restaurant',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '1',
#    'restaurant-booktime': '16:00',
#    'taxi-departure': 'huntingdon marriott',
#    'taxi-destination': 'maharajah tandoor'}},
#  {'query': ['well 4 stars sounds better than 0 to me , how about the alexander bed and breakfast . would you like to book there ?',
#    'as long as it has free wifi . i need a room for 2 nights for 4 people on the same day .'],
#   'corpus': {'hotel-bookday': 'train-day'},
#   'dialog_seen': {'train-day': 'monday',
#    'train-departure': 'broxbourne',
#    'train-destination': 'cambridge',
#    'train-bookpeople': '4',
#    'train-leaveat': '21:15',
#    'hotel-type': 'guesthouse',
#    'hotel-area': 'centre',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'cheap',
#    'hotel-stars': 'dontcare'}},
#  {'query': ['your reservation is all set for wednesday . your reference number is 68x7u9ig . is there anything else i can help you with ?',
#    'i need a hotel in the same price range as the restaurant that has free parking and free wifi for the same group for 3 nights starting from the same day .'],
#   'corpus': {'hotel-pricerange': 'restaurant-pricerange'},
#   'dialog_seen': {'restaurant-area': 'south',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-food': 'chinese',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '13:45',
#    'restaurant-name': 'good luck',
#    'restaurant-bookday': 'wednesday'}},
#  {'query': ['the acorn guest house would be perfect . shall i book it ?',
#    "yes , that would be great . i ' ll need it booked for the same group of people , 2 nights , and starting on the same day ."],
#   'corpus': {'hotel-bookday': 'restaurant-bookday',
#    'hotel-bookpeople': 'restaurant-bookpeople'},
#   'dialog_seen': {'restaurant-area': 'south',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-bookday': 'sunday',
#    'restaurant-name': 'lucky star',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '12:00',
#    'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse'}},
#  {'query': ['ok , will you be leaving from the restaurant or the college ? and what time of day would you like this booking to be ?',
#    'i want to leave the college by 07 : 00 so please go ahead and book that taxi for me'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'cotto',
#    'attraction-area': 'centre',
#    'attraction-name': 'old schools'}},
#  {'query': ['i have your rooms booked . the reference number is : ogbaz8xw . kis there anything else i can assist you with today ?',
#    'great i also need a taxi to commute between the two places .'],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'attraction-name': 'christs',
#    'attraction-type': 'college',
#    'hotel-internet': 'no',
#    'hotel-area': 'centre',
#    'hotel-parking': 'yes',
#    'hotel-name': 'alexander bed and breakfast',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '7',
#    'hotel-bookstay': '5'}},
#  {'query': ['yes it does .',
#    'i need to book a taxi to go between both places , needs to arrive after we finish at restaurant and i need car type and number'],
#   'corpus': {'taxi-leaveat': 'restaurant-booktime',
#    'taxi-destination': 'hotel-name',
#    'taxi-departure': 'restaurant-name'},
#   'dialog_seen': {'restaurant-food': 'gastropub',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'royal standard',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '13:45',
#    'hotel-pricerange': 'expensive',
#    'hotel-stars': '3',
#    'hotel-name': 'lensfield'}},
#  {'query': ["ok , i ' ve booked a white tesla for you , their contact number is 07752313537 . can i help you with anything else ?",
#    'actually , i know i said * after * we finish at the restaurant , but it turns out i need the taxi arrives at the restaurant at the reservation time - 13 : 45 on saturday'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'restaurant-food': 'gastropub',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'royal standard',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '2',
#    'restaurant-booktime': '13:45',
#    'hotel-pricerange': 'expensive',
#    'hotel-stars': '3',
#    'hotel-name': 'lensfield',
#    'taxi-departure': 'royal standard',
#    'taxi-destination': 'lensfield',
#    'taxi-leaveat': '13:45'}},
#  {'query': ['there are several fine restaurants . what area and what type of food would you enjoy ?',
#    "south area , and food type doesn ' t matter . i need it for 3 people at 15 : 45 on the same day , if that time doesn ' t work 14 : 45 and i ' d like a reference number ."],
#   'corpus': {'restaurant-bookday': 'train-day'},
#   'dialog_seen': {'train-day': 'sunday',
#    'train-arriveby': '19:30',
#    'train-departure': 'cambridge',
#    'restaurant-area': 'south',
#    'restaurant-pricerange': 'expensive',
#    'train-destination': 'kings lynn'}},
#  {'query': ['there are 33 options . what food type do you prefer ?',
#    "i don ' t care about the food type ."],
#   'corpus': {'restaurant-food': 'train-arriveby'},
#   'dialog_seen': {'train-day': 'friday',
#    'train-leaveat': '2:15 that afternoon',
#    'train-departure': 'cambridge',
#    'train-destination': 'stevenage',
#    'train-arriveby': 'dontcare',
#    'restaurant-area': 'centre',
#    'restaurant-pricerange': 'expensive'}},
#  {'query': ['okay . which site will you need to be picked up from , and what is your timeframe ?',
#    'i would like to leave the restaurant by 04 : 00 .'],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'restaurant-name'},
#   'dialog_seen': {'restaurant-food': 'portuguese',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-name': 'nandos',
#    'attraction-area': 'west',
#    'attraction-type': 'museum',
#    'attraction-name': 'cafe jello gallery'}},
#  {'query': ['do you have a price range or star rating in mind ?',
#    "i don ' t care , book it for the same group of people and 2 nights starting from the same day ."],
#   'corpus': {'hotel-bookday': 'restaurant-bookday',
#    'hotel-bookpeople': 'restaurant-bookpeople'},
#   'dialog_seen': {'restaurant-food': 'indian',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-area': 'centre',
#    'restaurant-name': 'kohinoor',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '1',
#    'restaurant-booktime': '12:00',
#    'hotel-area': 'dontcare',
#    'hotel-internet': 'yes',
#    'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse'}},
#  {'query': ['no problem ! i got that booked for your party of five . the reference number is jvgyc33y . do you need anything else ?',
#    'i am also looking for a train . it should should depart from london kings cross and should be on the same day .'],
#   'corpus': {'train-day': 'restaurant-bookday'},
#   'dialog_seen': {'restaurant-name': 'curry prince',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '18:30'}},
#  {'query': ['the gardenia is located at 2 rose crescent city centre . their post code is cb23ll . i can help you with the taxi . where are you departing from ?',
#    'i will be departing the hotel by 19 : 00 .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-name': 'alexander bed and breakfast',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'mediterranean',
#    'restaurant-name': 'gardenia'}},
#  {'query': ['i have booked the restaurant for you . the table will be reserved for 15 minutes . the reference number is y3mgyyh6 .',
#    'i also need a hotel that is near the restaurant .'],
#   'corpus': {'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-bookday': 'monday',
#    'restaurant-bookpeople': '1',
#    'restaurant-booktime': '14:45',
#    'restaurant-food': 'dontcare',
#    'restaurant-name': 'dojo noddle bar'}},
#  {'query': ['the star rating is 0 . would you still like me to book this hotel for you ?',
#    "i don ' t need a booking , but i need a taxi commuting between that hotel and the booked restaurant ."],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'cheap',
#    'restaurant-bookday': 'monday',
#    'restaurant-bookpeople': '1',
#    'restaurant-booktime': '14:45',
#    'restaurant-food': 'dontcare',
#    'restaurant-name': 'dojo noddle bar',
#    'hotel-area': 'centre',
#    'hotel-internet': 'yes',
#    'hotel-parking': 'yes',
#    'taxi-departure': 'el shaddai'}},
#  {'query': ["you ' re booked ! your reference number is 0h9b4720 . can i assist you with anything further ?",
#    "yes , i ' d like a taxi from the restaurant to the hotel , leaving by 18 : 45 ."],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-name': 'golden house',
#    'hotel-pricerange': 'cheap',
#    'hotel-type': 'guesthouse',
#    'taxi-departure': 'alexander bed and breakfast',
#    'hotel-bookday': 'tuesday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '5',
#    'hotel-name': 'el shaddai'}},
#  {'query': ['there are 4 in that area do you have a price range or type of hotel you prefer ?',
#    "the hotel doesn ' t need to include internet . it should be in the same area as the restaurant ."],
#   'corpus': {'hotel-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-food': 'asian oriental',
#    'restaurant-name': 'yippee noodle bar',
#    'restaurant-bookday': 'monday',
#    'restaurant-bookpeople': '6',
#    'restaurant-booktime': '19:00',
#    'hotel-area': 'west'}},
#  {'query': ['i have 5 different options for you . they vary in price range . did you have a certain price range in mind ?',
#    'the price does not matter . please make a recommendation and book it for the same group of people and 4 nights starting from the same day .'],
#   'corpus': {'hotel-bookday': 'restaurant-bookday',
#    'hotel-bookpeople': 'restaurant-bookpeople'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-food': 'asian oriental',
#    'restaurant-name': 'yippee noodle bar',
#    'restaurant-bookday': 'monday',
#    'restaurant-bookpeople': '6',
#    'restaurant-booktime': '19:00',
#    'hotel-area': 'centre',
#    'hotel-internet': 'dontcare'}},
#  {'query': ['booking was successful . the table will be reserved for 15 minutes . reference number is : yi8bkdr2 . is there anything else i can do for you ?',
#    'yes are there any parks in the same area as the restaurant ?'],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'north',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '4',
#    'restaurant-booktime': '12:15'}},
#  {'query': ['phone is 01223420060 . do you need anything else ?',
#    'yes , i would like a taxi to go from the two places and make sure it arrives to the restaurant by the booked time .'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'attraction-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'north',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '4',
#    'restaurant-booktime': '12:15',
#    'attraction-area': 'north',
#    'attraction-type': 'park',
#    'attraction-name': 'milton'}},
#  {'query': ['booking was successful . reference number is : yyxr9vmx',
#    'thanks . i also need a restaurant in the same area .'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-internet': 'yes',
#    'hotel-area': 'north',
#    'hotel-pricerange': 'dontcare',
#    'hotel-stars': '4',
#    'hotel-name': 'acorn guest house',
#    'hotel-bookday': 'wednesday',
#    'hotel-bookstay': '3',
#    'hotel-type': 'guesthouse',
#    'hotel-bookpeople': '5'}},
#  {'query': ['booking was successful . reference number is : tbicsa49 . is there anything else i can assist you with ?',
#    'i need a taxi from the hotel to the restaurant by 14 : 15 . please provide the car type and contact number'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-food': 'chinese',
#    'restaurant-name': 'ugly duckling',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '14:15',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'expensive',
#    'hotel-area': 'dontcare',
#    'hotel-internet': 'yes',
#    'hotel-name': 'huntingdon marriott hotel',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '8',
#    'hotel-bookstay': '3',
#    'hotel-stars': '4'}},
#  {'query': ['yes , the bell fry has free parking . would you like me to book a room for you ?',
#    'no , just the phone number and address . i am also looking for places to go in the same area as the hotel .'],
#   'corpus': {'attraction-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'west',
#    'hotel-internet': 'dontcare',
#    'hotel-pricerange': 'cheap',
#    'hotel-name': 'cambridge belfry'}},
#  {'query': ['the phone number is 01223334900',
#    'i will also need a taxi between them . i need to leave the hotel by 24 : 45 .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-stars': '4',
#    'hotel-type': 'guesthouse',
#    'hotel-parking': 'yes',
#    'hotel-name': 'acorn guest house',
#    'hotel-bookday': 'saturday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '3',
#    'attraction-type': 'college',
#    'taxi-destination': "christ's college"}},
#  {'query': ['okay , i will book for you then . how many days and people , and would you like it to start the same day ?',
#    "yes , i ' d like to book for 3 nights starting the same day . there will be 5 people ."],
#   'corpus': {'hotel-bookday': 'train-day'},
#   'dialog_seen': {'train-destination': 'cambridge',
#    'train-leaveat': '11:00',
#    'train-day': 'saturday',
#    'train-departure': 'norwich',
#    'train-bookpeople': '5',
#    'hotel-pricerange': 'expensive',
#    'hotel-stars': '3',
#    'hotel-internet': 'dontcare',
#    'hotel-parking': 'yes',
#    'hotel-area': 'centre',
#    'hotel-name': 'gonville'}},
#  {'query': ["ok de luca cucina and bar ' s address is 83 regent street and their phone number is 01223356666 . for places to visit , did you want it to be in the same area as the restaurant ?",
#    'i would like it to be in the same area yes .'],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-food': 'modern european',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'centre',
#    'restaurant-name': 'de luca cucina and bar'}},
#  {'query': ['it is a normal hotel and the phone number is 01223366611 .',
#    'thanks . can i also book a taxi to take me from the hotel to the old school . i want to leave the hotel by 21 : 00 .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'architecture',
#    'attraction-name': 'old schools',
#    'hotel-name': 'gonville hotel'}},
#  {'query': ['the taxi has been reserved . your taxi would be a black honda and you can contact it at 07973129543 .',
#    "thank you so much that ' s all i need ."],
#   'corpus': {'taxi-destination': 'attraction-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'architecture',
#    'attraction-name': 'old schools',
#    'hotel-name': 'gonville hotel',
#    'taxi-departure': 'gonville hotel',
#    'taxi-destination': 'old school',
#    'taxi-leaveat': '21:00'}},
#  {'query': ['certainly , i can help you with that . what time would you like to leave or arrive by ?',
#    'i would like to leave the park by 11 : 00 .'],
#   'corpus': {'taxi-destination': 'hotel-name',
#    'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-name': 'cambridge university botanic gardens',
#    'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-area': 'dontcare',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'dontcare',
#    'hotel-stars': 'dontcare',
#    'hotel-name': 'el shaddai',
#    'hotel-bookday': 'monday',
#    'hotel-bookpeople': '2',
#    'hotel-bookstay': '5'}},
#  {'query': ['ashley hotel looks like a good choice .',
#    'ok i would like to book it for thursday for 2 people for 3 night im also looking for a restaurant in the same price range as the hotel'],
#   'corpus': {'restaurant-pricerange': 'hotel-pricerange'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-parking': 'yes',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel'}},
#  {'query': ['booking was successful reference number is i53ii5mx . there are several restaurants is there any food preference ?',
#    'great . i also need to find a restaurant for the same number of people on the same day for 19 : 00 .'],
#   'corpus': {'restaurant-bookpeople': 'hotel-bookpeople'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-parking': 'yes',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel',
#    'hotel-name': 'ashley hotel',
#    'restaurant-pricerange': 'moderate',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '2',
#    'hotel-bookstay': '3'}},
#  {'query': ["absolutely ! your taxi has been booked . it ' s a blue ford and the contact number is 07118061422 . is there anything else that i can help you with ?",
#    'no not that i can think of you have done everything for me . thank you so much for your help .'],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'attraction-name': 'club salsa',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'modern european',
#    'restaurant-name': 'de luca cucina and bar',
#    'restaurant-bookday': 'friday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '13:00',
#    'taxi-arriveby': '13:00',
#    'taxi-departure': 'club salsa',
#    'taxi-destination': 'de luca cucina'}},
#  {'query': ['your room is booked , ref # khhjbqsz . can i help you with anything else today ?',
#    'thank you . i also would like to find some places to go in the area of the hotel .'],
#   'corpus': {'attraction-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'centre',
#    'hotel-type': 'hotel',
#    'hotel-parking': 'yes',
#    'hotel-name': 'university arms hotel',
#    'hotel-bookday': 'wednesday',
#    'hotel-bookpeople': '6',
#    'hotel-bookstay': '2'}},
#  {'query': ["of course , it ' s cb11pt .",
#    "thanks ! i ' ll also need a taxi from the theatre to the hotel , and i ' ll need to leave the theatre by 07 : 30 , please ."],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-area': 'centre',
#    'hotel-type': 'hotel',
#    'hotel-parking': 'yes',
#    'hotel-name': 'university arms hotel',
#    'hotel-bookday': 'wednesday',
#    'hotel-bookpeople': '6',
#    'hotel-bookstay': '2',
#    'attraction-area': 'centre',
#    'attraction-type': 'theatre',
#    'attraction-name': 'mumford theatre'}},
#  {'query': ['sure , the aylesbray lodge guest house is located at 5 mowbray road . can i be of any further assistance today ?',
#    'i also need a place to dine that is in the same area and price range as the hotel .'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'south', 'hotel-pricerange': 'moderate'}},
#  {'query': ['the phone number for saigon city is 01223356555 . the post code is cb41nl . can i help you with anyone else ?',
#    'i also need a taxi to commute between the hotel and restaurant .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-type': 'guesthouse',
#    'hotel-stars': '4',
#    'hotel-pricerange': 'cheap',
#    'hotel-name': 'worth house',
#    'hotel-bookday': 'tuesday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-name': 'saigon city'}},
#  {'query': ['ashley hotel will be expecting your party of 3 for 4 nights starting thursday . your reference number is k5jo25ul . is there anything else i can do for you ?',
#    'yes . i would like to find a restaurant in the same area and price range of the hotel that serves cuban food .'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel',
#    'hotel-name': 'ashley hotel',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '4',
#    'hotel-parking': 'yes'}},
#  {'query': ["i ' m sorry , there are no cuban restaurants in the city - is there another type of cuisine that you ' d like to try ?",
#    'what about one that has chinese food ?'],
#   'corpus': {'restaurant-pricerange': 'hotel-pricerange'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel',
#    'hotel-name': 'ashley hotel',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '4',
#    'hotel-parking': 'yes',
#    'restaurant-area': 'north',
#    'restaurant-food': 'cuban',
#    'restaurant-pricerange': 'dontcare'}},
#  {'query': ['where will you be leaving from ?',
#    'i need picked up at the hotel .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel',
#    'hotel-name': 'ashley hotel',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '4',
#    'hotel-parking': 'yes',
#    'restaurant-area': 'north',
#    'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'thursday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '17:15'}},
#  {'query': ['what time would you like to be picked up ?',
#    "i need to get to the restaurant by the reservation time , isn ' t it obvious ?"],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'hotel',
#    'hotel-name': 'ashley hotel',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '4',
#    'hotel-parking': 'yes',
#    'restaurant-area': 'north',
#    'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'thursday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '17:15',
#    'taxi-departure': 'ashley hotel'}},
#  {'query': ['they do indeed have a table at that time . your reference number is 0wbnizlj .',
#    'thank you . is there a museum in the same area as the restaurant that i could go to ?'],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'centre',
#    'restaurant-food': 'european',
#    'restaurant-name': 'hotel du vin and bistro',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '1',
#    'restaurant-booktime': '15:30'}},
#  {'query': ['ok , i booked you at the allenbell . the reference number is klnf2gx0 .',
#    'thank you . i also need a taxi to commute between the two places . i want to leave the attraction by 22 : 30 .'],
#   'corpus': {'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-name': "people's portrait exhibition at girton college",
#    'hotel-area': 'east',
#    'hotel-type': 'guesthouse',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'cheap',
#    'hotel-name': 'allenbell',
#    'hotel-bookday': 'wednesday',
#    'hotel-bookpeople': '2',
#    'hotel-bookstay': '5'}},
#  {'query': ['anything in particular you had in mind and when is your stay ?',
#    'i need to be in the same area as the attraction'],
#   'corpus': {'hotel-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'east',
#    'attraction-type': 'museum',
#    'attraction-name': 'gallery at twelve a high street'}},
#  {'query': ['it has been booked , your reference number is qfn3a3e9 .',
#    "great ! i ' ll need a taxi that will take me from the museum to the restaurant by 11 : 30 . can you book one for me ?"],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'museum',
#    'attraction-name': 'contemporary art museum',
#    'taxi-departure': 'contemporary art',
#    'restaurant-food': 'italian',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'pizza express',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '11:30'}},
#  {'query': ['its booked ! its a red volvo',
#    'can i please have the contact number for the taxi company ?'],
#   'corpus': {'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'museum',
#    'attraction-name': 'contemporary art museum',
#    'taxi-departure': 'contemporary art',
#    'restaurant-food': 'italian',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-name': 'pizza express',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '3',
#    'restaurant-booktime': '11:30',
#    'taxi-destination': 'pizza express',
#    'taxi-leaveat': '11:30'}},
#  {'query': ['great what is your departure city and what time would you like to leave ?',
#    "i would like to leave after 19 : 00 the departure city is peterborough . i ' m looking to leave the same day as the hotel booking ."],
#   'corpus': {'train-day': 'hotel-bookday'},
#   'dialog_seen': {'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'cheap',
#    'hotel-bookday': 'wednesday',
#    'hotel-bookpeople': '8',
#    'hotel-bookstay': '5',
#    'hotel-name': 'alexander bed and breakfast',
#    'train-destination': 'cambridge'}},
#  {'query': ['i have the a and b guesthouse that has wifi and is moderately priced .',
#    'sounds great , could you book it for 3 people for 2 nights starting on the same day as my train ?'],
#   'corpus': {'hotel-bookday': 'train-day'},
#   'dialog_seen': {'train-day': 'tuesday',
#    'train-departure': 'kings lynn',
#    'train-arriveby': '17:30',
#    'train-destination': 'cambridge',
#    'hotel-area': 'east',
#    'hotel-internet': 'yes',
#    'hotel-pricerange': 'moderate'}},
# ...
#   'corpus': {'train-day': 'hotel-bookday'},
#   'dialog_seen': {'hotel-name': 'city centre north b and b',
#    'hotel-bookday': 'saturday',
#    'hotel-bookpeople': '6',
#    'hotel-bookstay': '2',
#    'hotel-pricerange': 'cheap',
#    'train-departure': 'bishops stortford',
#    'train-destination': 'cambridge'}},
#  {'query': ['i can certainly book that for you . i just need to know for what day and how many people are in your party ?',
#    'it will just be one in the party . but i want to make sure i am out of the restaurant by 17 : 45 so can you make my reservation earlier ?'],
#   'corpus': {'restaurant-bookday': 'hotel-bookday'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-stars': '3',
#    'hotel-bookpeople': '5',
#    'hotel-name': 'hamilton lodge',
#    'hotel-bookday': 'saturday',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-booktime': '17:45',
#    'restaurant-name': 'golden wok'}},
#  {'query': ['i made that reservation for saturday at 17 : 45 . your reference number is zcm3ebe1 . remember the table will be held for 15 minutes only .',
#    'i also need a taxi leaving the restaurant at 17 : 45 .'],
#   'corpus': {'taxi-departure': 'restaurant-name'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-stars': '3',
#    'hotel-bookpeople': '5',
#    'hotel-name': 'hamilton lodge',
#    'hotel-bookday': 'saturday',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-booktime': '17:45',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '1'}},
#  {'query': ['what will your destination be in the taxi ?',
#    'i need to be picked up at the hotel and arrive to the restaurant by 17 : 45 .'],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-stars': '3',
#    'hotel-bookpeople': '5',
#    'hotel-name': 'hamilton lodge',
#    'hotel-bookday': 'saturday',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-booktime': '17:45',
#    'restaurant-name': 'golden wok',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '1',
#    'taxi-departure': 'golden wok',
#    'taxi-leaveat': '17:45'}},
#  {'query': ['it does have internet . would you like to book a room ?',
#    'i also need a taxi that will pick me up by by 8 : 15 from the guest house to the restaurant . i will appreciate to have the car type and the number .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'restaurant-area': 'east',
#    'restaurant-food': 'chinese',
#    'taxi-destination': 'yu garden',
#    'hotel-name': 'limehouse'}},
#  {'query': ["i always like to visit christ ' s college when i am in the area . the address is saint andrew ' s street . is there anything else i can do for you today ?",
#    'yes , please . i ; m also looking for an expensive place to dine in the same area as the college . can you help me with that ?'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-type': 'college', 'attraction-area': 'centre'}},
#  {'query': ['sure , what time would you like the reservation for ?',
#    'i would like reservations at 13 : 15 .'],
#   'corpus': {'restaurant-bookday': 'hotel-bookday',
#    'restaurant-bookpeople': 'hotel-bookpeople'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-name': 'acorn guest house',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '4',
#    'restaurant-food': 'indian',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'north'}},
#  {'query': ['i reserved a table at the nirala , your reference # is 6klpx1t4 , anything else ?',
#    'i also need a taxi to commute between the two places'],
#   'corpus': {'taxi-departure': 'hotel-name',
#    'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'hotel-area': 'north',
#    'hotel-parking': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-name': 'acorn guest house',
#    'hotel-bookday': 'thursday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '4',
#    'restaurant-food': 'indian',
#    'restaurant-pricerange': 'moderate',
#    'restaurant-area': 'north',
#    'restaurant-bookday': 'thursday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '13:15'}},
#  {'query': ['there are 63 different trains that leave birmingham new street and arrive by 15 : 00 , where did you want to go ?',
#    'cambridge , of course ! i need the make it to the restaurant booking !'],
#   'corpus': {'train-day': 'restaurant-bookday'},
#   'dialog_seen': {'restaurant-name': 'bloomsbury restaurant',
#    'restaurant-bookday': 'saturday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '19:15',
#    'train-arriveby': '1500',
#    'train-departure': 'birmingham new street'}},
#  {'query': ['the address is 41518 castle street city centre and the postcode is cb30ah .',
#    'thank you . i also need a hotel in the same price range , but it must include free parking .'],
#   'corpus': {'hotel-pricerange': 'restaurant-pricerange'},
#   'dialog_seen': {'restaurant-food': 'indian',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'west'}},
#  {'query': ['the post code is cb41jy . can i help with anything else ?',
#    'can i get a taxi from magdalene to hakka , please ? i need to make sure i get there for that reservation .'],
#   'corpus': {'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'restaurant-food': 'chinese',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-area': 'north',
#    'restaurant-name': 'hakka',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '18:30',
#    'attraction-type': 'college'}},
#  {'query': ['that cuts it down to 16 . i can recommend the acorn guest house , or do you have a pricerange or area of town you want to stay in ?',
#    'pick any of them , please . book it for 6 people and 3 nights , starting thursday .'],
#   'corpus': {'hotel-area': 'attraction-area'},
#   'dialog_seen': {'attraction-type': 'college',
#    'attraction-area': 'dontcare',
#    'attraction-name': 'corpus christi',
#    'hotel-type': 'guesthouse',
#    'hotel-parking': 'yes',
#    'hotel-stars': '4'}},
#  {'query': ['i recommend the oak bistro . they serve british food and the postcode is cb21eg . would you like me to book a table for you there ?',
#    'no thank you . i did want to go to an attraction in the same area of town .'],
#   'corpus': {'attraction-area': 'restaurant-area'},
#   'dialog_seen': {'restaurant-area': 'centre',
#    'restaurant-pricerange': 'moderate'}},
#  {'query': ['great your reference number is dk2czk2p .',
#    "thanks . i ' ll also need a taxi from the hotel to the restaurant . i need to make sure i get there by the 16 : 45 reservation ."],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'restaurant-name': 'the oak bistro',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '16:45',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'expensive',
#    'hotel-stars': '3',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '5',
#    'hotel-bookstay': '2'}},
#  {'query': ['yes it is and they have free entrance . where would the taxi be picking you up ?',
#    'i need to be picked up at the college and arrive at the restaurant by 18 : 45 .'],
#   'corpus': {'taxi-destination': 'restaurant-name',
#    'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'restaurant-food': 'indian',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-bookday': 'wednesday',
#    'restaurant-bookpeople': '6',
#    'restaurant-booktime': '19:45',
#    'restaurant-name': 'saffron brasserie',
#    'attraction-area': 'west',
#    'attraction-name': "churchill college's"}},
#  {'query': ['yes , both are 2 star rated , moderately priced and located in the north . both of them also offer free parking and free internet . would you prefer one of them ?',
#    'yes book the ashley hotel for the same group of people for 2 nights .'],
#   'corpus': {'hotel-bookpeople': 'train-bookpeople'},
#   'dialog_seen': {'train-arriveby': '11:45',
#    'train-day': 'monday',
#    'train-departure': 'london kings cross',
#    'train-destination': 'cambridge',
#    'train-bookpeople': '5',
#    'hotel-pricerange': 'moderate',
#    'hotel-stars': '2',
#    'hotel-name': 'ashley hotel'}},
#  {'query': ['gonville and caius college has a free entrance fee . their phone number is 01223332400 . is there anything else i can help you with today ?',
#    'i also need a taxi between them that leaves the hotel by 12 : 30 .'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-name': 'arbury lodge guesthouse',
#    'hotel-bookday': 'sunday',
#    'hotel-bookstay': '4',
#    'hotel-bookpeople': '1',
#    'attraction-area': 'centre',
#    'attraction-type': 'college',
#    'attraction-name': 'gonville and caius college'}},
#  {'query': ['there are 15 results for guesthouses in the moderate price range , what area are you looking to stay in ?',
#    "the area doesn ' t matter , but i would like 4 stars , please ."],
#   'corpus': {'hotel-area': 'attraction-area'},
#   'dialog_seen': {'attraction-type': 'college',
#    'attraction-area': 'dontcare',
#    'attraction-name': "king's college",
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'guesthouse'}},
#  {'query': ['the postcode to archway house is cb43pe and the phone is 01223575314 . would you like me to book this for you ?',
#    'i would love to book a taxi to commute between the two places . i want to leave the attraction by 08 : 45 . i need contact number and car type please .'],
#   'corpus': {'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-type': 'college',
#    'attraction-area': 'dontcare',
#    'attraction-name': "king's college",
#    'hotel-pricerange': 'moderate',
#    'hotel-type': 'guesthouse',
#    'hotel-area': 'dontcare',
#    'hotel-stars': '4',
#    'hotel-name': 'archway house',
#    'hotel-parking': 'yes'}},
#  {'query': ['the address is cambridge leisure park , clifton way . can i help with anything else ?',
#    'yes , i need to find a restaurant in the same area .'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'south',
#    'attraction-type': 'cinema',
#    'attraction-name': 'cineworld cinema'}},
#  {'query': ["i reserved a table for you at frankie ' s and bennys your confirmation # is heaz99bv , anything else ?",
#    'i would like to book a taxi from the hotel to the restaurant , one that gets me there in time for my reservation .'],
#   'corpus': {'taxi-arriveby': 'restaurant-booktime'},
#   'dialog_seen': {'hotel-area': 'south',
#    'hotel-pricerange': 'expensive',
#    'hotel-type': 'hotel',
#    'hotel-name': 'the lensfield hotel',
#    'taxi-departure': 'lensfield hotel',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '8',
#    'hotel-bookstay': '2',
#    'restaurant-area': 'south',
#    'restaurant-pricerange': 'expensive',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '8',
#    'restaurant-booktime': '9:15'}},
#  {'query': ['what day would you like to start your reservation ?',
#    'please start the reservation on monday . what is the reference number ? i also need a restaurant that serves australasian food at a moderate price in the same area as the hotel'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'centre',
#    'hotel-internet': 'yes',
#    'hotel-stars': '4',
#    'hotel-pricerange': 'dontcare',
#    'hotel-type': 'hotel',
#    'hotel-name': 'university arms hotel',
#    'hotel-bookpeople': '3',
#    'hotel-bookstay': '5'}},
#  {'query': ['the entrance fee is not listed would you like the phone number or address ?',
#    'yes please . i would like that very much and i also would like information on the ugly duckling restaurant .'],
#   'corpus': {'restaurant-area': 'attraction-area'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-type': 'theatre',
#    'attraction-name': 'mumford theatre'}},
#  {'query': ['your booking was successful . your reference number is lqs5d89f . what type of food would you like ?',
#    'i would prefer italian food and to be in the same area as the hotel . thank you .'],
#   'corpus': {'restaurant-area': 'hotel-area'},
#   'dialog_seen': {'hotel-type': 'guesthouse',
#    'hotel-stars': '4',
#    'hotel-area': 'north',
#    'hotel-internet': 'dontcare',
#    'hotel-name': 'home from home',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '4',
#    'hotel-bookstay': '5'}},
#  {'query': ['booked ! the reference number is 4jw5itol . anything else today ?',
#    'i would like a taxi to the restaurant .'],
#   'corpus': {'taxi-destination': 'restaurant-name'},
#   'dialog_seen': {'hotel-type': 'guesthouse',
#    'hotel-stars': '4',
#    'hotel-area': 'north',
#    'hotel-internet': 'dontcare',
#    'hotel-name': 'home from home',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '4',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-food': 'italian',
#    'restaurant-name': 'da vinci pizzeria',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '11:00'}},
#  {'query': ['for your taxi , i need to know your departure location and a time you want to leave after or arrive by',
#    'i want to depart from my hotel and arrive at the restaurant in time for my 11 : 00 reservation . please tell me the car type and contact number for my taxi'],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-type': 'guesthouse',
#    'hotel-stars': '4',
#    'hotel-area': 'north',
#    'hotel-internet': 'dontcare',
#    'hotel-name': 'home from home',
#    'hotel-bookday': 'sunday',
#    'hotel-bookpeople': '4',
#    'hotel-bookstay': '5',
#    'restaurant-area': 'north',
#    'restaurant-food': 'italian',
#    'restaurant-name': 'da vinci pizzeria',
#    'restaurant-bookday': 'sunday',
#    'restaurant-bookpeople': '5',
#    'restaurant-booktime': '11:00',
#    'taxi-destination': 'da vinci pizzeria'}},
#  {'query': ['i recommend the university arms hotel on regent street . would you like to book a room ?',
#    'i want want to book a taxi to commute between the two places .'],
#   'corpus': {'taxi-departure': 'attraction-name'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-name': 'cambridge contemporary art',
#    'attraction-type': 'museum',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'expensive',
#    'hotel-area': 'centre',
#    'hotel-type': 'dontcare',
#    'hotel-stars': 'dontcare'}},
#  {'query': ['where and when do you want to the taxi to pick you up ?',
#    'can the taxi pick me up at the hotel by 07 : 30 ?'],
#   'corpus': {'taxi-destination': 'attraction-name',
#    'taxi-departure': 'taxi-destination'},
#   'dialog_seen': {'attraction-area': 'centre',
#    'attraction-name': 'cambridge contemporary art',
#    'attraction-type': 'museum',
#    'hotel-parking': 'yes',
#    'hotel-pricerange': 'expensive',
#    'hotel-area': 'centre',
#    'hotel-type': 'dontcare',
#    'hotel-stars': 'dontcare',
#    'taxi-destination': 'university arms hotel',
#    'taxi-departure': 'cambridge contemporary art'}},
#  {'query': ["great , can you tell me when you ' d like to book ?",
#    'can you please give me the address and phone number of the location ? i would also like to find some college - related attractions in that area .'],
#   'corpus': {'attraction-area': 'hotel-area'},
#   'dialog_seen': {'hotel-area': 'east',
#    'hotel-stars': '4',
#    'hotel-internet': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-name': 'finches bed and breakfast'}},
#  {'query': ["no , unfortunately . that ' s the only place .",
#    "i ' d like to book a taxi leaving the hotel by 21 : 00 . i ' d also like the contact number and car type ."],
#   'corpus': {'taxi-departure': 'hotel-name'},
#   'dialog_seen': {'hotel-area': 'east',
#    'hotel-stars': '4',
#    'hotel-internet': 'yes',
#    'hotel-type': 'guesthouse',
#    'hotel-name': 'finches bed and breakfast',
#    'attraction-area': 'east',
#    'attraction-type': 'college'}},
#  ...]

# %%
path = 'D:\Python4work\paper_modified_test\\all_datasets\gte_training_data'

# %%
import os, json


def generate_the_query_jsonl(processed_data, path):
    corpus_save_path = os.path.join(path, 'query.jsonl')
    i = 0
    with open(corpus_save_path, 'w', encoding='utf-8') as file_obj:
        for item in processed_data:
            query_text = ' '.join(item['query'])
            json_data = json.dumps({'_id':'query_{a}'.format(a=i),'text': query_text,'title':'', 'metadata':'', 'processed_data_index':i}, ensure_ascii=False)
            file_obj.write(json_data + '\n')
            i = i + 1

generate_the_query_jsonl(processed_data, path)

# %%
def generate_the_corpus_jsonl(slot_des, path):
    corpus_save_path = os.path.join(path, 'corpus.jsonl')
    i = 0
    with open(corpus_save_path, 'w', encoding='utf-8') as file_obj:
        for slot, des in slot_des.items():
            query_text = des
            json_data = json.dumps({'_id':'corpus_{a}'.format(a=i),'text': query_text,'title':'', 'metadata':'', "corpus_id": slot}, ensure_ascii=False)
            file_obj.write(json_data + '\n')
            i = i + 1
generate_the_corpus_jsonl(slot_des, path)

# %%
slot_des2corpus_id = {}
i = 0
for k,v in slot_des.items():
    slot_des2corpus_id[k] = 'corpus_{a}'.format(a=i)
    i = i+1
slot_des2corpus_id
# Out:
# {'hotel-pricerange': 'corpus_0',
#  'hotel-type': 'corpus_1',
#  'hotel-parking': 'corpus_2',
#  'hotel-bookstay': 'corpus_3',
#  'hotel-bookday': 'corpus_4',
#  'hotel-bookpeople': 'corpus_5',
#  'hotel-area': 'corpus_6',
#  'hotel-stars': 'corpus_7',
#  'hotel-internet': 'corpus_8',
#  'hotel-name': 'corpus_9',
#  'train-destination': 'corpus_10',
#  'train-day': 'corpus_11',
#  'train-departure': 'corpus_12',
#  'train-arriveby': 'corpus_13',
#  'train-bookpeople': 'corpus_14',
#  'train-leaveat': 'corpus_15',
#  'attraction-type': 'corpus_16',
#  'attraction-area': 'corpus_17',
#  'attraction-name': 'corpus_18',
#  'restaurant-bookpeople': 'corpus_19',
#  'restaurant-bookday': 'corpus_20',
#  'restaurant-booktime': 'corpus_21',
#  'restaurant-food': 'corpus_22',
#  'restaurant-pricerange': 'corpus_23',
#  'restaurant-name': 'corpus_24',
#  'restaurant-area': 'corpus_25',
#  'taxi-leaveat': 'corpus_26',
#  'taxi-destination': 'corpus_27',
#  'taxi-departure': 'corpus_28',
#  'taxi-arriveby': 'corpus_29',
#  'bus-people': 'corpus_30',
#  'bus-leaveAt': 'corpus_31',
#  'bus-destination': 'corpus_32',
#  'bus-day': 'corpus_33',
#  'bus-arriveBy': 'corpus_34',
#  'bus-departure': 'corpus_35',
#  'hospital-department': 'corpus_36'}

# %%
def generate_hard_negatives_jsonl(processed_data, path):
    hard_save_path = os.path.join(path, 'train', 'hard-negatives.jsonl')
    with open(hard_save_path, 'w', encoding='utf-8') as file_obj:
        for i in range(len(processed_data)):
            qid = 'query_{a}'.format(a=i)
            diag_seen_slots = list(processed_data[i]['dialog_seen'].keys())
            refer_slot = list(processed_data[i]['corpus'].values())

            dict1 = {k:0 for k in diag_seen_slots}
            for k in refer_slot:
                dict1[k] = dict1[k] + 1
            neg_list = [slot_des2corpus_id[k] for k,v in dict1.items() if v == 0]
            pos_list = [slot_des2corpus_id[k] for k in refer_slot]
            json_data = json.dumps({"qid":qid, 'pos':pos_list, 'neg':{'nature': neg_list}}, ensure_ascii=False)
            file_obj.write(json_data + '\n')

generate_hard_negatives_jsonl(processed_data, path)

# %%
def generate_tsv_file(processed_data, path):
    qrels_tsv_path = os.path.join(path, 'qrels', 'train.tsv')
    all_positive_data = []
    with open(qrels_tsv_path, 'w', newline='') as file_obj:
        for i in range(len(processed_data)):
            for k,v in processed_data[i]['corpus'].items():
                all_positive_data.append(['query_{a}'.format(a=i), slot_des2corpus_id[v], '1'])

        all_positive_data = [['query_id','corpus_id', 'score']] + all_positive_data
        for i in all_positive_data:
            file_obj.writelines('\t'.join(i)+'\n')
generate_tsv_file(processed_data, path)

# %%
from sentence_transformers import SentenceTransformer, util

model_path = 'D:\Python4work\save\\train_bi-encoder-mnrl-gte-margin_3.0-2024-02-15_17-10-51\\340'
model = SentenceTransformer(model_path)
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 300, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %%
candidate = {'hotel-name': 'alyesbray lodge guest house',
            'hotel-bookday': 'sunday',
            'hotel-bookstay': '5',
            'hotel-bookpeople': '8',
            'restaurant-name': 'don pasquale pizzeria'}


candidate = {
    'hotel-name': 'name of the hotel',
    'hotel-bookday': 'day of the hotel booking',
    'hotel-bookstay': "length of stay at the hotel",
    'hotel-bookpeople': "number of people for the hotel booking",
    'restaurant-name': "name of the restaurant"
}

query_embedding = model.encode(processed_data[0]['query'][0])

corpus_embedding = {k:model.encode(v) for k,v in candidate.items()}

# %%
result = {k:util.cos_sim(v, query_embedding) for k,v in corpus_embedding.items()}

# %%
result
# Out:
# {'hotel-name': tensor([[0.8176]]),
#  'hotel-bookday': tensor([[0.8188]]),
#  'hotel-bookstay': tensor([[0.7873]]),
#  'hotel-bookpeople': tensor([[0.8043]]),
#  'restaurant-name': tensor([[0.8207]])}

# %%
result_sorted = [(k,v[0][0].item()) for k,v in result.items()]
result_sorted = sorted(result_sorted, key=lambda x: x[1],reverse=True)
result_sorted
# Out:
# [('restaurant-name', 0.8207498788833618),
#  ('hotel-bookday', 0.8187683820724487),
#  ('hotel-name', 0.8175947666168213),
#  ('hotel-bookpeople', 0.8042743802070618),
#  ('hotel-bookstay', 0.7872970104217529)]

# %%
result_sorted = [(k,v[0][0].item()) for k,v in result.items()]
result_sorted = sorted(result_sorted, key=lambda x: x[1],reverse=True)
result_sorted
# Out:
# [('hotel-bookday', 0.5616703033447266),
#  ('hotel-bookpeople', 0.5115121603012085),
#  ('hotel-bookstay', 0.4944835305213928),
#  ('hotel-name', 0.44273337721824646),
#  ('restaurant-name', 0.44158700108528137)]

# %%
# Out:
# "yes , i do . i ' ll need it booked for the same day , same people , and we ' d like to eat at 19 : 00 . a very nice place in the centre . need a reservation ?"

# %%
processed_data[0]['corpus']
# Out:
# {'restaurant-bookday': 'hotel-bookday',
#  'restaurant-bookpeople': 'hotel-bookpeople'}

# %%
result_list = []

for i in range(len(processed_data)):
    query_embedding = model.encode(' '.join(processed_data[i]['query']))
    corpus_embedding = {k:model.encode(slot_des[k]) for k,v in processed_data[i]['dialog_seen'].items()}
    result = {k:util.cos_sim(v, query_embedding) for k,v in corpus_embedding.items()}
    #print(result)
    result_sorted = [(k,v[0][0]) for k,v in result.items()]
    result_sorted = sorted(result_sorted, key=lambda x: x[1],reverse=True)
    result_sorted = [i[0] for i in result_sorted][:len(list(processed_data[i]['corpus'].values()))]
    result_list.append({'test':result_sorted.copy(), 'gold':list(processed_data[i]['corpus'].values())})

# %%
result_list
# Out:
# [{'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area', 'restaurant-pricerange'],
#   'gold': ['restaurant-pricerange', 'restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-pricerange', 'restaurant-area'],
#   'gold': ['restaurant-pricerange', 'restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['train-leaveat'], 'gold': ['train-departure']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-parking']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['attraction-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime', 'hotel-name'],
#   'gold': ['restaurant-booktime', 'hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['train-day'], 'gold': ['train-arriveby']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['taxi-departure'], 'gold': ['taxi-leaveat']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-name', 'restaurant-bookpeople', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['hotel-name']},
#  {'test': ['train-bookpeople'], 'gold': ['train-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['train-day', 'train-bookpeople'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-parking'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name', 'hotel-bookstay'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['train-destination'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-area', 'hotel-bookpeople'],
#   'gold': ['hotel-bookstay', 'hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['attraction-area', 'attraction-type'],
#   'gold': ['attraction-type', 'attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['train-destination'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['train-departure'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['taxi-destination'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['train-day', 'train-bookpeople'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name', 'attraction-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-name'], 'gold': ['attraction-area']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['train-departure'], 'gold': ['hotel-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-pricerange', 'restaurant-area'],
#   'gold': ['restaurant-pricerange', 'restaurant-area']},
#  {'test': ['hotel-type'], 'gold': ['hotel-type']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-parking'], 'gold': ['hotel-parking']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area', 'restaurant-pricerange'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-pricerange']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['taxi-destination'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['train-leaveat']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-bookday']},
#  {'test': ['train-departure'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-parking']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-food']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'taxi-leaveat'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name', 'taxi-destination'],
#   'gold': ['attraction-type', 'hotel-name']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'restaurant-bookpeople'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['train-bookpeople', 'train-day', 'train-destination'],
#   'gold': ['train-day', 'train-bookpeople', 'train-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['taxi-leaveat'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name'], 'gold': ['train-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-name', 'restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-bookpeople', 'train-destination'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookday']},
#  {'test': ['taxi-departure', 'restaurant-name'],
#   'gold': ['restaurant-booktime', 'restaurant-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'restaurant-bookpeople'],
#   'gold': ['restaurant-name', 'taxi-destination', 'restaurant-booktime']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookstay']},
#  {'test': ['restaurant-name', 'restaurant-booktime', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-bookpeople'], 'gold': ['train-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area', 'restaurant-pricerange'],
#   'gold': ['restaurant-pricerange', 'restaurant-area']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['taxi-destination'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['hotel-pricerange']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'attraction-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-type']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name', 'restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['attraction-area'], 'gold': ['attraction-type']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookstay']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-booktime', 'hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-food'], 'gold': ['restaurant-food']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-booktime', 'hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['train-leaveat'], 'gold': ['train-destination']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-bookpeople', 'restaurant-bookday'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name', 'hotel-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['train-arriveby'], 'gold': ['hotel-bookday']},
#  {'test': ['train-destination'], 'gold': ['hotel-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name', 'hotel-bookstay'],
#   'gold': ['hotel-area', 'taxi-destination']},
#  {'test': ['hotel-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-pricerange', 'train-departure'],
#   'gold': ['hotel-pricerange', 'hotel-pricerange']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-name', 'restaurant-booktime'],
#   'gold': ['attraction-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['taxi-departure'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['train-bookpeople'], 'gold': ['train-bookpeople']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-type']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-bookstay'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'taxi-destination']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area', 'hotel-pricerange'],
#   'gold': ['restaurant-bookday', 'restaurant-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-parking'], 'gold': ['hotel-area']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookday']},
#  {'test': ['train-arriveby'], 'gold': ['train-destination']},
#  {'test': ['restaurant-booktime', 'hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['train-departure'], 'gold': ['train-departure']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['train-day', 'train-bookpeople'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-name', 'restaurant-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['taxi-destination'], 'gold': ['taxi-destination']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['hotel-name', 'attraction-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-area'], 'gold': ['restaurant-food']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange', 'hotel-area'],
#   'gold': ['hotel-pricerange', 'hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['train-leaveat'], 'gold': ['restaurant-food']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'attraction-name'],
#   'gold': ['attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-pricerange'], 'gold': ['attraction-type']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['train-bookpeople', 'train-day'],
# ...
#  {'test': ['hotel-pricerange', 'hotel-area'],
#   'gold': ['hotel-area', 'hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-type'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-parking']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['taxi-departure'], 'gold': ['attraction-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-internet'], 'gold': ['train-leaveat']},
#  {'test': ['train-destination'], 'gold': ['train-day']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name', 'hotel-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-bookpeople'], 'gold': ['restaurant-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name', 'hotel-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-bookpeople'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name'], 'gold': ['restaurant-name']},
#  {'test': ['taxi-leaveat'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name', 'restaurant-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['attraction-name', 'restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'restaurant-booktime'],
#   'gold': ['hotel-name', 'restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-destination'], 'gold': ['train-arriveby']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['hotel-area', 'hotel-pricerange'],
#   'gold': ['hotel-pricerange', 'hotel-area']},
#  {'test': ['restaurant-name', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-name']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-name', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name', 'attraction-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'attraction-name', 'restaurant-booktime']},
#  {'test': ['hotel-name', 'attraction-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-arriveby'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-bookpeople', 'hotel-bookday'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-booktime', 'restaurant-name'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['train-bookpeople', 'train-day'],
#   'gold': ['train-day', 'train-bookpeople']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['attraction-name'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-pricerange'], 'gold': ['hotel-pricerange']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-pricerange']},
#  {'test': ['taxi-destination', 'hotel-name'],
#   'gold': ['hotel-name', 'taxi-destination']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['taxi-destination'], 'gold': ['taxi-departure']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-name', 'hotel-name'],
#   'gold': ['attraction-name', 'hotel-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['train-bookpeople'], 'gold': ['train-bookpeople']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name', 'restaurant-booktime'],
#   'gold': ['restaurant-name', 'restaurant-booktime']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-bookday'], 'gold': ['restaurant-bookday']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['hotel-name', 'hotel-pricerange'],
#   'gold': ['restaurant-name', 'hotel-name']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['train-day'], 'gold': ['train-day']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-bookday'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-booktime'], 'gold': ['hotel-bookday']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['restaurant-name']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-bookpeople', 'hotel-name'],
#   'gold': ['hotel-bookday', 'hotel-bookpeople']},
#  {'test': ['restaurant-booktime', 'hotel-name'],
#   'gold': ['hotel-name', 'restaurant-booktime']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-bookday']},
#  {'test': ['restaurant-pricerange'], 'gold': ['restaurant-pricerange']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-area'], 'gold': ['restaurant-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name', 'attraction-name'],
#   'gold': ['restaurant-name', 'attraction-name']},
#  {'test': ['train-bookpeople'], 'gold': ['train-bookpeople']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  {'test': ['hotel-pricerange'], 'gold': ['attraction-area']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['restaurant-booktime'], 'gold': ['restaurant-booktime']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['attraction-area'], 'gold': ['attraction-area']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['restaurant-name'], 'gold': ['restaurant-name']},
#  {'test': ['restaurant-name'], 'gold': ['hotel-name']},
#  {'test': ['attraction-name'], 'gold': ['attraction-name']},
#  {'test': ['attraction-name', 'taxi-destination'],
#   'gold': ['attraction-name', 'taxi-destination']},
#  {'test': ['hotel-area'], 'gold': ['hotel-area']},
#  {'test': ['hotel-name'], 'gold': ['hotel-name']},
#  ...]

# %%
result_save_name = os.path.join(model_path, 'result_list.json')
with open(result_save_name, 'w', encoding='utf-8') as file_obj:
    json_data = json.dumps(result_list, ensure_ascii=False)
    file_obj.write(json_data)

# %%
correct_one = 0
for i in result_list:
    if set(i['test']) == set(i['gold']):
        correct_one = correct_one + 1
correct_one
# Out:
# 1771

# %%
correct_one = 0
for i in result_list:
    if set(i['test']) == set(i['gold']):
        correct_one = correct_one + 1
correct_one

# %%
set(['attraction-name', 'taxi-destination']) in set(['taxi-destination', 'taxi-departure'])
# Out:
# False

# %%
set(['taxi-departure', 'taxi-destination']).issubset(set(['taxi-destination', 'taxi-departure']))
# Out:
# True

# %%
processed_data[2]
# Out:
# {'query': ['i have made your booking here is the information : booking was successful . the table will be reserved for 15 minutes . reference number is : vvsoh0tq .',
#   "what ' s a good college to visit near the restaurant ?"],
#  'corpus': {'attraction-area': 'restaurant-area'},
#  'dialog_seen': {'restaurant-food': 'british',
#   'restaurant-area': 'centre',
#   'restaurant-pricerange': 'moderate',
#   'restaurant-name': 'cotto',
#   'restaurant-bookday': 'friday',
#   'restaurant-bookpeople': '8',
#   'restaurant-booktime': '12:30'}}

# %%
processed_data[1]
# Out:
# {'query': ["great . one more thing . can you book a taxi between the two places ? i ' d like to arrive at the restaurant in time for my reservation .",
#   'booking was successful . the table will be reserved for 15 minutes . reference number is : gvm0pam2 .'],
#  'corpus': {'taxi-destination': 'restaurant-name',
#   'taxi-departure': 'hotel-name',
#   'taxi-arriveby': 'restaurant-booktime'}}

# %%
len(processed_data)
# Out:
# 2150
